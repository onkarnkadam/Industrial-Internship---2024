# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sales_data = pd.read_csv("C:/Users/Onkar Kadam/Desktop/Sem 6 Internship/DataSet/Sales - 9-2-24 - CSV.csv", encoding="latin1")

# %%
print("First few rows of the DataFrame:")
print(sales_data.head())
# Out:
# First few rows of the DataFrame:
#         Date Months                                          Customers  \
# 0   4/3/2018    Apr  Dr. Babasaheb Ambedkar Multistate Co-Op Credit...
# 1  4/11/2018    Apr                                          Amit Bhat
# 2  4/12/2018    Apr                                       Kakade Laser
# 3  4/17/2018    Apr                               SiGa Systems Pvt Ltd
# 4  4/18/2018    Apr       Orient Exchange & Financial Services Pvt Ltd
#
#        Products Sub.Products  H/S.ware  Product Quantity Location  \
# 0    M Paper Li    Microsoft  Software                24   Kalamb
# 1    M Paper Li    Microsoft  Software                12     Pune
# 2  M Retail/Box    Microsoft  Software                 1     Pune
# 3    M Paper Li    Microsoft  Software                 4     Pune
# 4    HP Printer      Printer  Hardware                 1     Pune
#
#    Postal Code Vch Type       Vch No.    Amount  Year Old/New  \
# ...

# %%
print(sales_data.dtypes)
# Out:
# Date                 object
# Months               object
# Customers            object
# Products             object
# Sub.Products         object
# H/S.ware             object
# Product Quantity      int64
# Location             object
# Postal Code           int64
# Vch Type             object
# Vch No.              object
# Amount              float64
# Year                  int64
# Old/New              object
# Old/New Customer     object
# Customer Count      float64
# dtype: object

# %%
print("\nSummary statistics of numerical columns:")
print(sales_data.describe())
# Out:
# Summary statistics of numerical columns:
#        Product Quantity  Postal Code        Amount         Year  \
# count       1961.000000       1961.0  1.961000e+03  1961.000000
# mean         519.475778         91.0  8.256952e+04  2021.080061
# std        11281.932413          0.0  1.838916e+05     1.729461
# min            1.000000         91.0  1.600000e+02  2018.000000
# 25%            1.000000         91.0  6.608000e+03  2019.000000
# 50%            2.000000         91.0  2.504900e+04  2022.000000
# 75%            5.000000         91.0  7.788000e+04  2023.000000
# max       250000.000000         91.0  2.704560e+06  2023.000000
#
#        Customer Count
# count           449.0
# mean              1.0
# std               0.0
# min               1.0
# 25%               1.0
# 50%               1.0
# 75%               1.0
# max               1.0

# %%
try:
    # Load the sales data into a pandas DataFrame
    sales_data = pd.read_csv("C:/Users/Onkar Kadam/Desktop/Sem 6 Internship/DataSet/Sales - 9-2-24 - CSV.csv", encoding="latin1")

    # Continue with exploratory data analysis...
except TypeError as e:
    print(f"Error: {e}")
    print("Please check the data type of the 'Amount' column and ensure it is numeric.")

# %%
print(sales_data['Amount'].unique())
# Out:
# [338188. 156836.  10502. ...  53902.  22420.  89100.]

# %%
sales_data = pd.read_csv("C:/Users/Onkar Kadam/Desktop/Sem 6 Internship/DataSet/Sales - 9-2-24 - CSV.csv", encoding="latin1", dtype={'Amount': float64})

# %%
print("\nBox plot for numerical columns:")
for col in numeric_cols:
    plt.figure(figsize=(8, 6))
    sns.boxplot(data=sales_data[col], color='skyblue')
    plt.title(f'Box plot of {col}')
    plt.xlabel(col)
    plt.show()
# Out:
# Box plot for numerical columns:

# %%
print("\nCorrelation matrix:")
correlation_matrix = sales_data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix of Sales Data")
plt.show()
# Out:
# Correlation matrix:

# %%
print("\nPairplot for numerical columns:")
sns.pairplot(sales_data[numeric_cols])
plt.show()
# Out:
# Pairplot for numerical columns:

# %%
print("\nCount plot for categorical columns:")
categorical_cols = sales_data.select_dtypes(include=['object']).columns
for col in categorical_cols:
    plt.figure(figsize=(8, 6))
    sns.countplot(data=sales_data, x=col, palette='viridis')
    plt.title(f'Count plot of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation='vertical')
    plt.show()
# Out:
# Count plot for categorical columns:
# ) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
